# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from data_import import load_data
from model_dfs import prepare_nig_inputs
#from nig_em_paper import EM_algo, one_year_pd_timeseries
from nig_gibbs import gibbs_sampler

# %%
# Load Accenture dataset
ret_daily, bs = load_data(
    xlsx_path= None,
    verbose=True
)

print(ret_daily.head())
print("-"*40)
print(bs.head())
print("-"*40)

# Load ECB 1Y risk-free yield data

# If first time, call API to get data, otherwise:
path = Path.cwd() / "data/derived" / "ecb_riskfree_1y_daily.csv"
df_rf= pd.read_csv(path, parse_dates=["date"])
print(df_rf.head())
# Out:
#       country_iso          isin       date                       company  \
# 41651         DEU  DE0005190003 2010-01-05  BAYERISCHE MOTOREN WERKE AKT
# 41652         DEU  DE0005190003 2010-01-06  BAYERISCHE MOTOREN WERKE AKT
# 41653         DEU  DE0005190003 2010-01-07  BAYERISCHE MOTOREN WERKE AKT
# 41654         DEU  DE0005190003 2010-01-08  BAYERISCHE MOTOREN WERKE AKT
# 41655         DEU  DE0005190003 2010-01-11  BAYERISCHE MOTOREN WERKE AKT
#
#         gvkey   shares_out   close  mcap_reported  shares_out_filled  \
# 41651  100022  601995196.0  32.310   1.945046e+10        601995196.0
# 41652  100022  601995196.0  32.810   1.975146e+10        601995196.0
# 41653  100022  601995196.0  33.100   1.992604e+10        601995196.0
# 41654  100022  601995196.0  32.655   1.965815e+10        601995196.0
# 41655  100022  601995196.0  32.170   1.936619e+10        601995196.0
#
#                mcap  bad_day  logret_close  logret_mcap
# 41651  1.945046e+10    False      0.008080     0.008080
# 41652  1.975146e+10    False      0.015357     0.015357
# 41653  1.992604e+10    False      0.008800     0.008800
# 41654  1.965815e+10    False     -0.013535    -0.013535
# 41655  1.936619e+10    False     -0.014964    -0.014964
# ----------------------------------------
#    country_iso status data_format industry_format consolidation          isin  \
# 15         DEU      A    HIST_STD            INDL             C  DE0005190003
# 16         DEU      A    HIST_STD            INDL             C  DE0005190003
# 17         DEU      A    HIST_STD            INDL             C  DE0005190003
# 18         DEU      A    HIST_STD            INDL             C  DE0005190003
# 19         DEU      A    HIST_STD            INDL             C  DE0005190003
#
#          date                       company   gvkey  fyear final_date  \
# 15 2010-12-31  BAYERISCHE MOTOREN WERKE AKT  100022   2010 2011-03-19
# 16 2011-12-31  BAYERISCHE MOTOREN WERKE AKT  100022   2011 2012-03-17
# 17 2012-12-31  BAYERISCHE MOTOREN WERKE AKT  100022   2012 2013-03-23
# 18 2013-12-31  BAYERISCHE MOTOREN WERKE AKT  100022   2013 2014-03-22
# 19 2014-12-31  BAYERISCHE MOTOREN WERKE AKT  100022   2014 2015-03-20
#
#     liabilities_total  liabilities_total_raw  liabilities_scale_used
# 15       8.576700e+10                85767.0               1000000.0
# 16       9.632600e+10                96326.0               1000000.0
# 17       1.014480e+11               101448.0               1000000.0
# 18       1.027250e+11               102725.0               1000000.0
# 19       1.173660e+11               117366.0               1000000.0
# ----------------------------------------
#         date      r_1y
# 0 2010-01-04  0.008330
# 1 2010-01-05  0.007934
# 2 2010-01-06  0.007782
# 3 2010-01-07  0.007491
# 4 2010-01-08  0.007417

# %%
# Build NIG inputs and fill missing liabilities
df_nig_panel, nig_em_data = prepare_nig_inputs(ret_daily, bs, df_rf)
print(df_nig_panel.head(50))
# Out:
#      gvkey       date             E          isin  \
# 0   100022 2010-01-05  1.945046e+10  DE0005190003
# 1   100080 2010-01-05  4.578810e+10  DE000BAY0017
# 2   100312 2010-01-05  1.765719e+09  DE0007030009
# 3   100581 2010-01-05  4.701386e+10  FR0000120321
# 4   100957 2010-01-05  3.539016e+10  ES0144580Y14
# 5   101202 2010-01-05  2.188290e+10  FR0000120073
# 6   101204 2010-01-05  7.372136e+10  FR0000120578
# 7   101248 2010-01-05  8.674785e+09  FR0000121667
# 8   101305 2010-01-05  6.061525e+09  FR0000073272
# 9   101336 2010-01-05  2.149174e+10  FR0000121972
# 10  101361 2010-01-05  4.566206e+09  NL0000395903
# 11  102296 2010-01-05  2.096499e+10  FR0000125486
# 12  103487 2010-01-05  4.002267e+10  DE0007164600
# 13  132740 2010-01-05  4.605613e+09  DE0006231004
# 14   14140 2010-01-05  9.784074e+10  ES0113900J37
# 15   14447 2010-01-05  3.839475e+10  FR0000121014
# 16   15181 2010-01-05  4.973802e+10  ES0113211835
# 17   15532 2010-01-05  6.765080e+10  FR0000131104
# 18   15549 2010-01-05  3.945920e+10  IT0005239360
# 19   15617 2010-01-05  2.838868e+10  NL0011821202
# 20   15677 2010-01-05  2.141808e+10  DE0008430026
# 21   15724 2010-01-05  4.031086e+10  DE0008404005
# 22   16348 2010-01-05  3.723653e+10  IT0000072618
# 23   17436 2010-01-05  4.056920e+10  DE000BASF111
# 24   17452 2010-01-05  2.772032e+10  FR0000120644
# 25   17828 2010-01-05  3.951761e+10  DE0007100000
# 26   19349 2010-01-05  5.988947e+10  DE0007236101
# 27  201794 2010-01-05  3.827167e+10  IT0003128367
# 28  203053 2010-01-05  9.935137e+09  FR0000052292
# 29  220833 2010-01-05  1.138059e+10  NL0000235190
# 30  220940 2010-01-05  4.693304e+10  FR0000133308
# 31  221244 2010-01-05  8.310067e+09  DE000A1EWWW0
# 32  221616 2010-01-05  4.583747e+10  DE0005557508
# 33  222379 2010-01-05  1.085274e+10  FR0000121485
# 34   23667 2010-01-05  1.114534e+10  NL0011794037
# 35   23671 2010-01-05  3.458467e+10  FI0009000681
# 36  241456 2010-01-05  1.692622e+10  DE0005552004
# 37  241637 2010-01-05  5.869872e+10  BE0974293251
# 38  243774 2010-01-05  1.141140e+10  DE0005810055
# 39  245663 2010-01-05  2.721461e+10  ES0148396007
# 40   24625 2010-01-05  1.076103e+11  FR0000120271
# 41   61214 2010-01-05  1.048234e+10  NL0010273215
# 42   61616 2010-01-05  7.301769e+10  IT0003132476
# 43   63120 2010-01-05  3.911171e+10  FR0000120628
# 44  100022 2010-01-06  1.975146e+10  DE0005190003
# 45  100080 2010-01-06  4.549867e+10  DE000BAY0017
# 46  100312 2010-01-06  1.730476e+09  DE0007030009
# 47  100581 2010-01-06  4.660093e+10  FR0000120321
# 48  100957 2010-01-06  3.534289e+10  ES0144580Y14
# 49  101202 2010-01-06  2.174813e+10  FR0000120073
#
#                          company country_iso         r             L
# 0   BAYERISCHE MOTOREN WERKE AKT         DEU  0.007934  8.576700e+10
# 1                       BAYER AG         DEU  0.007934  3.254300e+10
# 2                 RHEINMETALL AG         DEU  0.007934  3.105000e+09
# 3                      LOREAL SA         FRA  0.007934  9.178700e+09
# 4                   IBERDROLA SA         ESP  0.007934  6.203788e+10
# 5               L'AIR LIQUIDE SA         FRA  0.007934  1.342510e+10
# 6                         SANOFI         FRA  0.007934  3.197600e+10
# 7       ESSILORLUXOTTICA SOCIETE         FRA  0.007934  2.168860e+09
# 8                      SAFRAN SA         FRA  0.007934  1.380600e+10
# 9         SCHNEIDER ELECTRIC S E         FRA  0.007934  1.606200e+10
# 10             WOLTERS KLUWER NV         NLD  0.007934  4.926000e+09
# 11                      VINCI SA         FRA  0.007934  4.338860e+10
# 12                        SAP SE         DEU  0.007934  1.101700e+10
# 13      INFINEON TECHNOLOGIES AG         DEU  0.007934  2.368000e+09
# 14            BANCO SANTANDER SA         ESP  0.007934  1.136586e+12
# 15    LVMH MOET HENNESSY LOUIS V         FRA  0.007934  1.896000e+10
# 16  BANCO BILBAO VIZCAYA ARGENTA         ESP  0.007934  5.152630e+11
# 17                   BNP PARIBAS         FRA  0.007934  1.912529e+12
# 18                 UNICREDIT SPA         ITA  0.007934  8.617843e+11
# 19                  ING GROEP NV         NLD  0.007934  1.198745e+12
# 20                  MUNICH RE CO         DEU  0.007934  2.133300e+11
# 21                    ALLIANZ SE         DEU  0.007934  5.783830e+11
# 22           INTESA SANPAOLO SPA         ITA  0.007934  6.041570e+11
# 23                       BASF SE         DEU  0.007934  3.673600e+10
# 24                     DANONE SA         FRA  0.007934  1.611200e+10
# 25        MERCEDES BENZ GROUP AG         DEU  0.007934  9.787700e+10
# 26                    SIEMENS AG         DEU  0.007934  7.373100e+10
# 27                      ENEL SPA         ITA  0.007934  1.145070e+11
# 28          HERMES INTERNATIONAL         FRA  0.007934  7.555000e+08
# 29                     AIRBUS SE         NLD  0.007934  7.425100e+10
# 30                     ORANGE SA         FRA  0.007934  6.272700e+10
# 31                     ADIDAS AG         DEU  0.007934  5.995000e+09
# 32              DEUTSCHE TELEKOM         DEU  0.007934  8.478400e+10
# 33                     KERING SA         FRA  0.007934  1.304330e+10
# 34    KONINKLIJKE AHOLD DELHAIZE         NLD  0.007934  8.815000e+09
# 35                     NOKIA OYJ         FIN  0.007934  2.289200e+10
# 36              DEUTSCHE POST AG         DEU  0.007934  2.706700e+10
# 37          ANHEUSER-BUSCH INBEV         BEL  0.007934  7.554300e+10
# 38            DEUTSCHE BOERSE AG         DEU  0.007934  1.454402e+11
# 39       IND DE DISENO TEXTIL SA         ESP  0.007934  2.964891e+09
# 40              TOTALENERGIES SE         FRA  0.007934  8.244700e+10
# 41               ASML HOLDING NV         NLD  0.007934  3.406450e+09
# 42                       ENI SPA         ITA  0.007934  7.613200e+10
# 43                        AXA SA         FRA  0.007934  6.729300e+11
# 44  BAYERISCHE MOTOREN WERKE AKT         DEU  0.007782  8.576700e+10
# 45                      BAYER AG         DEU  0.007782  3.254300e+10
# 46                RHEINMETALL AG         DEU  0.007782  3.105000e+09
# 47                     LOREAL SA         FRA  0.007782  9.178700e+09
# 48                  IBERDROLA SA         ESP  0.007782  6.203788e+10
# 49              L'AIR LIQUIDE SA         FRA  0.007782  1.342510e+10

# %%
import numpy as np
import pandas as pd

import nig_base, nig_em, nig_pd


def nig_firm_timeseries_em_every_15d(
    *,
    dates: np.ndarray,
    E: np.ndarray,
    L: np.ndarray,
    r: np.ndarray,
    start_params: dict,
    daycount: int = 250,
    train_min: int = 250,         # first PD at end of first year
    window_max: int = 250,        # expand until 2y, then roll 2y
    em_every: int = 20,           # <-- your 15 trading days
    tau_mode: str = "one_year",
    liability_mode: str = "timevarying",
    max_iter: int = 4,
    min_iter: int = 2,
    tol: float = 1e-3,
) -> pd.DataFrame:
    """
    One-firm full-history driver:
      - EM recalibration every `em_every` trading days
      - daily A_t^(1Y) and PD_t computed using last calibrated params in-between

    Returns a daily dataframe with A_hat, theta, PD_physical, PD_risk_neutral
    and the (piecewise-constant) parameters used each day.
    """

    # Ensure EM uses the same implementations you refactored into nig_base
    nig_em.get_asset_path = nig_base.get_asset_path
    nig_em.update_theta = nig_base.update_theta

    dates = np.asarray(dates)
    E = np.asarray(E, dtype=float)
    L = np.asarray(L, dtype=float)
    r = np.asarray(r, dtype=float)

    n = len(dates)
    if not (len(E) == len(L) == len(r) == n):
        raise ValueError("dates, E, L, r must have the same length")

    # outputs (daily)
    A_hat = np.full(n, np.nan, dtype=float)
    theta = np.full(n, np.nan, dtype=float)
    pd_p = np.full(n, np.nan, dtype=float)
    pd_q = np.full(n, np.nan, dtype=float)

    alpha_s = np.full(n, np.nan, dtype=float)
    beta1_s = np.full(n, np.nan, dtype=float)
    delta_s = np.full(n, np.nan, dtype=float)
    mu_s = np.full(n, np.nan, dtype=float)
    is_recalib = np.zeros(n, dtype=bool)
    em_converged = np.full(n, False, dtype=bool)
    em_n_iter = np.full(n, np.nan, dtype=float)

    # schedule of EM end-indices (first one at train_min-1)
    first_end = train_min - 1
    if first_end >= n:
        # not enough data for even 1 year
        return pd.DataFrame({"date": dates, "A_hat": A_hat, "PD_physical": pd_p, "PD_risk_neutral": pd_q})

    em_end_idxs = list(range(first_end, n, em_every))

    params_cur = dict(start_params)

    # We compute in blocks: [t_cal, t_next) share the SAME params_cur
    for k, t_cal in enumerate(em_end_idxs):
        # window start index: expanding until window_max, then rolling
        w0 = 0 if t_cal < window_max else (t_cal - window_max + 1)

        # --- EM recalibration on [w0, t_cal] ---
        out = nig_em.EM_algo(
            E_series=E,
            L_face_series=L,
            rf_series=r,
            dates=dates,
            start_params=params_cur,          # warm-start params from last calibration
            start_date=dates[w0],
            end_date=dates[t_cal],
            tau_mode=tau_mode,
            liability_mode=liability_mode,
            daycount=daycount,
            max_iter=max_iter,
            min_iter=min_iter,
            tol=tol,
        )

        params_cur = dict(out["params"])
        is_recalib[t_cal] = True
        em_converged[t_cal] = bool(out.get("converged", False))
        em_n_iter[t_cal] = float(out.get("n_iter", np.nan))

        # on EM day, we already have A at the end of the window
        A_cal = float(out["A_win"][-1])
        A_hat[t_cal] = A_cal

        # determine block end (exclusive)
        t_next = em_end_idxs[k + 1] if (k + 1) < len(em_end_idxs) else n

        # --- compute A_hat for the in-between days using fixed params_cur ---
        # We compute A for [t_cal, t_next-1] in ONE call (warm-started at A_cal).
        # Then we overwrite the first element with A_cal (exact value from EM output).
        if t_next - 1 >= t_cal:
            A_block = nig_base.get_asset_path(
                params=params_cur,
                rf_series=r,
                dates=dates,
                E_series=E,
                L_face_series=L,
                start_date=dates[t_cal],
                end_date=dates[t_next - 1],
                tau_mode=tau_mode,
                liability_mode=liability_mode,
                daycount=daycount,
                warm_start=True,
                A0=A_cal,
                warn=False,
            )
            idx_block = np.arange(t_cal, t_next, dtype=int)
            A_hat[idx_block] = A_block
            A_hat[t_cal] = A_cal  # ensure exact consistency on the calibration day

        # --- daily theta + PDs on the same block ---
        # theta is computed from r_t and params_cur (Esscher tilt); PD_Q uses beta1+theta.
        theta_block = nig_base.update_theta(params_cur, r[t_cal:t_next], enforce_pricing=True, warn=False)
        theta[t_cal:t_next] = theta_block

        alpha = float(params_cur["alpha"])
        beta1 = float(params_cur["beta1"])
        delta = float(params_cur["delta"])
        mu = float(params_cur["beta0"])

        alpha_s[t_cal:t_next] = alpha
        beta1_s[t_cal:t_next] = beta1
        delta_s[t_cal:t_next] = delta
        mu_s[t_cal:t_next] = mu

        for t in range(t_cal, t_next):
            A0 = float(A_hat[t])
            Lt = float(L[t])

            if not (np.isfinite(A0) and np.isfinite(Lt) and A0 > 0.0 and Lt > 0.0):
                continue

            # Physical PD: beta=beta1
            pd_p[t] = nig_pd.compute_pd_physical(A0=A0, L=Lt, T=1.0, params=params_cur)

            # Risk-neutral PD: beta=beta1+theta_t
            th = float(theta[t])
            if np.isfinite(th):
                params_t = dict(params_cur)
                params_t["theta"] = th
                pd_q[t] = nig_pd.compute_pd_risk_neutral(A0=A0, L=Lt, T=1.0, params=params_t)

    # Assemble output
    df_out = pd.DataFrame({
        "date": dates,
        "E": E,
        "L": L,
        "r": r,
        "A_hat": A_hat,
        "theta": theta,
        "PD_physical": pd_p,
        "PD_risk_neutral": pd_q,
        "alpha": alpha_s,
        "beta1": beta1_s,
        "delta": delta_s,
        "beta0_mu": mu_s,
        "is_recalib": is_recalib,
        "em_converged": em_converged,
        "em_n_iter": em_n_iter,
    })

    return df_out

# %%
df = df_nig_panel.copy()

df["date"] = pd.to_datetime(df["date"])
df = df.sort_values(["gvkey", "date"])

gv = df["gvkey"].iloc[0]          # pick any firm id
g = df[df["gvkey"] == gv].copy().sort_values("date")

daycount = 250
two_years = 2 * daycount

g2 = g.iloc[-daycount:].copy()

import cProfile, pstats, io, time

kwargs = dict(
    dates=g2["date"].to_numpy(),
    E=g2["E"].to_numpy(float),
    L=g2["L"].to_numpy(float),
    r=g2["r"].to_numpy(float),
    start_params={"alpha": 1.0, "beta1": 0.0, "delta": 0.2, "beta0": 0.0},
    em_every=20,
    daycount=250,
    train_min=250,
    window_max=500,
    max_iter=5,
    min_iter=1,
    tol=1e-2,
)

pr = cProfile.Profile()
pr.enable()
res = nig_firm_timeseries_em_every_15d(**kwargs)
pr.disable()

s = io.StringIO()
pstats.Stats(pr, stream=s).sort_stats("cumtime").print_stats(30)
print(s.getvalue())

res.loc[res["is_recalib"], ["date", "alpha", "beta1", "delta", "beta0_mu", "em_converged", "em_n_iter"]].head()
res[["date", "A_hat", "PD_physical", "PD_risk_neutral"]].dropna().head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 33
#      31 pr = cProfile.Profile()
#      32 pr.enable()
# ---> 33 res = nig_firm_timeseries_em_every_15d(**kwargs)
#      34 pr.disable()
#      36 s = io.StringIO()
#
# Cell In[4], line 108, in nig_firm_timeseries_em_every_15d(dates, E, L, r, start_params, daycount, train_min, window_max, em_every, tau_mode, liability_mode, max_iter, min_iter, tol)
#     104 # --- compute A_hat for the in-between days using fixed params_cur ---
#     105 # We compute A for [t_cal, t_next-1] in ONE call (warm-started at A_cal).
#     106 # Then we overwrite the first element with A_cal (exact value from EM output).
#     107 if t_next - 1 >= t_cal:
# --> 108     A_block = nig_base.get_asset_path(
#     109         params=params_cur,
#     110         rf_series=r,
#     111         dates=dates,
#     112         E_series=E,
#     113         L_face_series=L,
#     114         start_date=dates[t_cal],
#     115         end_date=dates[t_next - 1],
#     116         tau_mode=tau_mode,
#     117         liability_mode=liability_mode,
#     118         daycount=daycount,
#     119         warm_start=True,
#     120         A0=A_cal,
#     121         warn=False,
#     122     )
#     123     idx_block = np.arange(t_cal, t_next, dtype=int)
#     124     A_hat[idx_block] = A_block
#
# File c:\Users\vkeenan\OneDrive - Delft University of Technology\Documents\University\QRM\Accenture Project\code\nig_base.py:312, in get_asset_path(params, rf_series, dates, E_series, L_face_series, start_date, end_date, daycount, discounting, tau_mode, liability_mode, warm_start, A0, warn)
#     309 n = len(E)
#     311 if n < 3:
# --> 312     raise ValueError("Training window too short")
#     314 # --- define tau_t ---
#     315 h = 1.0 / daycount
#
# ValueError: Training window too short
